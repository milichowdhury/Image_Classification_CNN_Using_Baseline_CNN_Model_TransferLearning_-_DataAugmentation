# %%
# Dataset - https://www.kaggle.com/datasets/salader/dogs-vs-cats
# Label of DOG is 1 and Label of cat is 0

# %% [markdown]
# ##Image_Classification_CNN_of_Dogs&Cats

# %%
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/

# %%
# !kaggle datasets download -d salader/dogs-vs-cats
# Out:
# Warning: Your Kaggle API key is readable by other users on this system! To fix this, you can run 'chmod 600 /root/.kaggle/kaggle.json'
# Dataset URL: https://www.kaggle.com/datasets/salader/dogs-vs-cats
# License(s): unknown
# Downloading dogs-vs-cats.zip to /content
#  98% 1.05G/1.06G [00:12<00:00, 90.5MB/s]
# 100% 1.06G/1.06G [00:12<00:00, 89.4MB/s]

# %%
import zipfile
zip_ref = zipfile.ZipFile('/content/dogs-vs-cats.zip', 'r')
zip_ref.extractall('/content')
zip_ref.close()

# %%
import tensorflow as tf
from tensorflow import keras
from keras import Sequential
from keras.layers import Dense,Conv2D,MaxPooling2D,Flatten,BatchNormalization,Dropout
from keras.applications.vgg16 import VGG16

# %%
# Generators (Divide the data into batches, so a batch load in RAM)
train_ds = keras.utils.image_dataset_from_directory(
    directory = '/content/train',
    labels='inferred',
    label_mode = 'int',
    batch_size=32,
    image_size=(256,256)
)

validation_ds = keras.utils.image_dataset_from_directory(
    directory = '/content/test',
    labels='inferred',
    label_mode = 'int',
    batch_size=32,
    image_size=(256,256)
)
# Out:
# Found 20000 files belonging to 2 classes.
# Found 5000 files belonging to 2 classes.

# %%
# Normalize. This function process normalizes the pixel values of images to the range [0, 1]
def process(image,label):
    image = tf.cast(image/255. ,tf.float32)
    return image,label

train_ds = train_ds.map(process)
validation_ds = validation_ds.map(process)

# %%
# Create CNN model

model = Sequential()

model.add(Conv2D(32,kernel_size=(3,3),padding='valid',activation='relu',input_shape=(256,256,3)))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2),strides=2,padding='valid'))

model.add(Conv2D(64,kernel_size=(3,3),padding='valid',activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2),strides=2,padding='valid'))

model.add(Conv2D(128,kernel_size=(3,3),padding='valid',activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2),strides=2,padding='valid'))

model.add(Flatten())

model.add(Dense(128,activation='relu'))
model.add(Dropout(0.1))
model.add(Dense(64,activation='relu'))
model.add(Dropout(0.1))
model.add(Dense(32,activation='relu'))
model.add(Dropout(0.1))
model.add(Dense(1,activation='sigmoid'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 254, 254, 32)      896
#
#  batch_normalization (Batch  (None, 254, 254, 32)      128
#  Normalization)
#
#  max_pooling2d (MaxPooling2  (None, 127, 127, 32)      0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 125, 125, 64)      18496
#
#  batch_normalization_1 (Bat  (None, 125, 125, 64)      256
#  chNormalization)
#
#  max_pooling2d_1 (MaxPoolin  (None, 62, 62, 64)        0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 60, 60, 128)       73856
#
#  batch_normalization_2 (Bat  (None, 60, 60, 128)       512
#  chNormalization)
#
#  max_pooling2d_2 (MaxPoolin  (None, 30, 30, 128)       0
#  g2D)
#
#  flatten (Flatten)           (None, 115200)            0
#
#  dense (Dense)               (None, 128)               14745728
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense_2 (Dense)             (None, 32)                2080
#
#  dropout_2 (Dropout)         (None, 32)                0
#
#  dense_3 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 14850241 (56.65 MB)
# Trainable params: 14849793 (56.65 MB)
# Non-trainable params: 448 (1.75 KB)
# _________________________________________________________________

# %%
model.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])

# %%
history = model.fit(train_ds,epochs=10,validation_data=validation_ds)
# Out:
# Epoch 1/10
# 625/625 [==============================] - 74s 103ms/step - loss: 1.2695 - accuracy: 0.5685 - val_loss: 0.6658 - val_accuracy: 0.5972
# Epoch 2/10
# 625/625 [==============================] - 64s 102ms/step - loss: 0.5910 - accuracy: 0.6822 - val_loss: 0.5530 - val_accuracy: 0.7254
# Epoch 3/10
# 625/625 [==============================] - 67s 107ms/step - loss: 0.5043 - accuracy: 0.7582 - val_loss: 0.4959 - val_accuracy: 0.7620
# Epoch 4/10
# 625/625 [==============================] - 66s 106ms/step - loss: 0.4426 - accuracy: 0.7988 - val_loss: 0.5488 - val_accuracy: 0.7472
# Epoch 5/10
# 625/625 [==============================] - 64s 102ms/step - loss: 0.3700 - accuracy: 0.8383 - val_loss: 0.4913 - val_accuracy: 0.7780
# Epoch 6/10
# 625/625 [==============================] - 64s 102ms/step - loss: 0.2907 - accuracy: 0.8775 - val_loss: 0.4801 - val_accuracy: 0.7936
# Epoch 7/10
# 625/625 [==============================] - 64s 101ms/step - loss: 0.2180 - accuracy: 0.9144 - val_loss: 0.6019 - val_accuracy: 0.8094
# Epoch 8/10
# 625/625 [==============================] - 64s 102ms/step - loss: 0.1410 - accuracy: 0.9492 - val_loss: 0.6019 - val_accuracy: 0.7852
# Epoch 9/10
# 625/625 [==============================] - 66s 106ms/step - loss: 0.0873 - accuracy: 0.9688 - val_loss: 0.7625 - val_accuracy: 0.8126
# Epoch 10/10
# 625/625 [==============================] - 63s 101ms/step - loss: 0.0625 - accuracy: 0.9772 - val_loss: 0.9341 - val_accuracy: 0.8094

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['accuracy'],color='red',label='train')
plt.plot(history.history['val_accuracy'],color='blue',label='validation')
plt.legend()
plt.show()

# %%
plt.plot(history.history['loss'],color='red',label='train')
plt.plot(history.history['val_loss'],color='blue',label='validation')
plt.legend()
plt.show()

# %% [markdown]
# DOG IMAGE TEST

# %%
# Download the image from GitHub
# !wget https://github.com/SayakKDutta/Image_Classification_CNN/blob/main/DATASET/TEST/dog.jpg?raw=true
# Out:
# --2024-05-04 04:23:34--  https://github.com/SayakKDutta/Image_Classification_CNN/blob/main/DATASET/TEST/dog.jpg?raw=true
# Resolving github.com (github.com)... 140.82.116.4
# Connecting to github.com (github.com)|140.82.116.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://github.com/SayakKDutta/Image_Classification_CNN/raw/main/DATASET/TEST/dog.jpg [following]
# --2024-05-04 04:23:34--  https://github.com/SayakKDutta/Image_Classification_CNN/raw/main/DATASET/TEST/dog.jpg
# Reusing existing connection to github.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/SayakKDutta/Image_Classification_CNN/main/DATASET/TEST/dog.jpg [following]
# --2024-05-04 04:23:34--  https://raw.githubusercontent.com/SayakKDutta/Image_Classification_CNN/main/DATASET/TEST/dog.jpg
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 76428 (75K) [image/jpeg]
# Saving to: ‘dog.jpg?raw=true’
#
# dog.jpg?raw=true    100%[===================>]  74.64K  --.-KB/s    in 0.008s
#
# 2024-05-04 04:23:35 (8.77 MB/s) - ‘dog.jpg?raw=true’ saved [76428/76428]

# %%
import cv2

# %%
test_img = cv2.imread('/content/dog.jpg?raw=true')

# %%
plt.imshow(test_img)

# %%
test_img.shape
# Out:
# (510, 900, 3)

# %%
test_img = cv2.resize(test_img,(256,256)) #resize

# %%
test_input = test_img.reshape((1,256,256,3)) #Batches (4d tensor) [one image with dimension 256,256,3]

# %%
model.predict(test_input) #dog assigned 1, cat assigned 0
# Out:
# 1/1 [==============================] - 1s 627ms/step
# array([[1.]], dtype=float32)

# %% [markdown]
# CAT IMAGE TEST

# %%
# !wget https://github.com/SayakKDutta/Image_Classification_CNN/blob/main/DATASET/TEST/cat.jpg?raw=true -O cat.jpg
# Out:
# --2024-05-04 05:08:29--  https://github.com/SayakKDutta/Image_Classification_CNN/blob/main/DATASET/TEST/cat.jpg?raw=true
# Resolving github.com (github.com)... 140.82.116.4
# Connecting to github.com (github.com)|140.82.116.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://github.com/SayakKDutta/Image_Classification_CNN/raw/main/DATASET/TEST/cat.jpg [following]
# --2024-05-04 05:08:29--  https://github.com/SayakKDutta/Image_Classification_CNN/raw/main/DATASET/TEST/cat.jpg
# Reusing existing connection to github.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/SayakKDutta/Image_Classification_CNN/main/DATASET/TEST/cat.jpg [following]
# --2024-05-04 05:08:30--  https://raw.githubusercontent.com/SayakKDutta/Image_Classification_CNN/main/DATASET/TEST/cat.jpg
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5595458 (5.3M) [application/octet-stream]
# Saving to: ‘cat.jpg’
#
# cat.jpg             100%[===================>]   5.34M  --.-KB/s    in 0.05s
#
# 2024-05-04 05:08:30 (111 MB/s) - ‘cat.jpg’ saved [5595458/5595458]

# %%
test_img1 = cv2.imread('/content/cat.jpg')

# %%
plt.imshow(test_img1)

# %%
test_img1.shape
# Out:
# (6000, 4000, 3)

# %%
test_img1 = cv2.resize(test_img1,(256,256)) #resize

# %%
test_input1 = test_img1.reshape((1,256,256,3))

# %%
model.predict(test_input1)
# Out:
# 1/1 [==============================] - 0s 18ms/step
# array([[0.]], dtype=float32)

# %% [markdown]
# ##Using Transfer Learning

# %%
conv_base = VGG16(
    weights ='imagenet',
    include_top = False, #ignoringdenselayers
    input_shape = (150,150,3)
)

# %%
conv_base.summary()
# Out:
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 150, 150, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 150, 150, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 150, 150, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 75, 75, 64)        0
#
#  block2_conv1 (Conv2D)       (None, 75, 75, 128)       73856
#
#  block2_conv2 (Conv2D)       (None, 75, 75, 128)       147584
#
#  block2_pool (MaxPooling2D)  (None, 37, 37, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 37, 37, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 37, 37, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 37, 37, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 18, 18, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 18, 18, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 18, 18, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 18, 18, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 9, 9, 512)         0
#
#  block5_conv1 (Conv2D)       (None, 9, 9, 512)         2359808
#
#  block5_conv2 (Conv2D)       (None, 9, 9, 512)         2359808
#
#  block5_conv3 (Conv2D)       (None, 9, 9, 512)         2359808
#
#  block5_pool (MaxPooling2D)  (None, 4, 4, 512)         0
#
# =================================================================
# Total params: 14714688 (56.13 MB)
# Trainable params: 14714688 (56.13 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
new_model = Sequential()

new_model.add(conv_base)
new_model.add(Flatten())
new_model.add(Dense(256,activation='relu'))
new_model.add(Dense(1,activation='sigmoid'))

# %%
new_model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg16 (Functional)          (None, 4, 4, 512)         14714688
#
#  flatten_1 (Flatten)         (None, 8192)              0
#
#  dense_4 (Dense)             (None, 256)               2097408
#
#  dense_5 (Dense)             (None, 1)                 257
#
# =================================================================
# Total params: 16812353 (64.13 MB)
# Trainable params: 16812353 (64.13 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
conv_base.trainable = False #dont retrain its weight

# %%
new_model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg16 (Functional)          (None, 4, 4, 512)         14714688
#
#  flatten_1 (Flatten)         (None, 8192)              0
#
#  dense_4 (Dense)             (None, 256)               2097408
#
#  dense_5 (Dense)             (None, 1)                 257
#
# =================================================================
# Total params: 16812353 (64.13 MB)
# Trainable params: 2097665 (8.00 MB)
# Non-trainable params: 14714688 (56.13 MB)
# _________________________________________________________________

# %%
# generators
new_train_ds = keras.utils.image_dataset_from_directory(
    directory = '/content/train',
    labels='inferred',
    label_mode = 'int',
    batch_size=32,
    image_size=(150,150)
)

new_validation_ds = keras.utils.image_dataset_from_directory(
    directory = '/content/test',
    labels='inferred',
    label_mode = 'int',
    batch_size=32,
    image_size=(150,150)
)
# Out:
# Found 20000 files belonging to 2 classes.
# Found 5000 files belonging to 2 classes.

# %%
# Normalize
def process(image,label):
    image = tf.cast(image/255. ,tf.float32)
    return image,label

new_train_ds = new_train_ds.map(process)
new_validation_ds = new_validation_ds.map(process)

# %%
new_model.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])

# %%
new_history = new_model.fit(new_train_ds,epochs=10,validation_data=new_validation_ds)
# Out:
# Epoch 1/10
# 625/625 [==============================] - 70s 103ms/step - loss: 0.2714 - accuracy: 0.8902 - val_loss: 0.2254 - val_accuracy: 0.9046
# Epoch 2/10
# 625/625 [==============================] - 55s 88ms/step - loss: 0.1899 - accuracy: 0.9214 - val_loss: 0.2331 - val_accuracy: 0.9004
# Epoch 3/10
# 625/625 [==============================] - 53s 85ms/step - loss: 0.1605 - accuracy: 0.9345 - val_loss: 0.2059 - val_accuracy: 0.9164
# Epoch 4/10
# 625/625 [==============================] - 53s 84ms/step - loss: 0.1394 - accuracy: 0.9429 - val_loss: 0.2108 - val_accuracy: 0.9128
# Epoch 5/10
# 625/625 [==============================] - 53s 85ms/step - loss: 0.1124 - accuracy: 0.9550 - val_loss: 0.2663 - val_accuracy: 0.9036
# Epoch 6/10
# 625/625 [==============================] - 63s 101ms/step - loss: 0.0895 - accuracy: 0.9652 - val_loss: 0.2351 - val_accuracy: 0.9098
# Epoch 7/10
# 625/625 [==============================] - 63s 100ms/step - loss: 0.0647 - accuracy: 0.9761 - val_loss: 0.2606 - val_accuracy: 0.9120
# Epoch 8/10
# 625/625 [==============================] - 53s 85ms/step - loss: 0.0538 - accuracy: 0.9799 - val_loss: 0.2957 - val_accuracy: 0.9126
# Epoch 9/10
# 625/625 [==============================] - 63s 101ms/step - loss: 0.0383 - accuracy: 0.9872 - val_loss: 0.3179 - val_accuracy: 0.9124
# Epoch 10/10
# 625/625 [==============================] - 53s 84ms/step - loss: 0.0325 - accuracy: 0.9891 - val_loss: 0.3987 - val_accuracy: 0.9026

# %%
import matplotlib.pyplot as plt

plt.plot(new_history.history['accuracy'],color='red',label='train')
plt.plot(new_history.history['val_accuracy'],color='blue',label='validation')
plt.legend()
plt.show()

# %%
plt.plot(new_history.history['loss'],color='red',label='train')
plt.plot(new_history.history['val_loss'],color='blue',label='validation')
plt.legend()
plt.show()

# %% [markdown]
# TRANSFER LEARNING TEST

# %% [markdown]
# CAT

# %%
plt.imshow(test_img1)

# %%
test_img1.shape
# Out:
# (256, 256, 3)

# %%
test_img1 = cv2.resize(test_img1,(150,150))

# %%
test_input1 = test_img1.reshape((1,150,150,3))

# %%
new_model.predict(test_input1)
# Out:
# 1/1 [==============================] - 1s 975ms/step
# array([[0.]], dtype=float32)

# %% [markdown]
# My Own Pet (CAT)

# %%
# !wget https://github.com/SayakKDutta/Image_Classification_CNN/blob/main/DATASET/TEST/myhousecat.jpg?raw=true
# Out:
# --2024-05-04 05:59:35--  https://github.com/SayakKDutta/Image_Classification_CNN/blob/main/DATASET/TEST/myhousecat.jpg?raw=true
# Resolving github.com (github.com)... 140.82.116.3
# Connecting to github.com (github.com)|140.82.116.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://github.com/SayakKDutta/Image_Classification_CNN/raw/main/DATASET/TEST/myhousecat.jpg [following]
# --2024-05-04 05:59:35--  https://github.com/SayakKDutta/Image_Classification_CNN/raw/main/DATASET/TEST/myhousecat.jpg
# Reusing existing connection to github.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/SayakKDutta/Image_Classification_CNN/main/DATASET/TEST/myhousecat.jpg [following]
# --2024-05-04 05:59:35--  https://raw.githubusercontent.com/SayakKDutta/Image_Classification_CNN/main/DATASET/TEST/myhousecat.jpg
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.111.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 156216 (153K) [image/jpeg]
# Saving to: ‘myhousecat.jpg?raw=true’
#
# myhousecat.jpg?raw= 100%[===================>] 152.55K  --.-KB/s    in 0.02s
#
# 2024-05-04 05:59:36 (8.61 MB/s) - ‘myhousecat.jpg?raw=true’ saved [156216/156216]

# %%
test_img_pet = cv2.imread('/content/myhousecat.jpg?raw=true')

# %%
plt.imshow(test_img_pet)

# %%
test_img_pet.shape
# Out:
# (1600, 1283, 3)

# %%
test_imgpet = cv2.resize(test_img_pet,(150,150))

# %%
test_inputpet = test_imgpet.reshape((1,150,150,3))

# %%
new_model.predict(test_inputpet)
# Out:
# 1/1 [==============================] - 0s 25ms/step
# array([[0.]], dtype=float32)

# %% [markdown]
# DOG

# %%
plt.imshow(test_img)

# %%
test_img = cv2.resize(test_img,(150,150))

# %%
test_input = test_img.reshape((1,150,150,3))

# %%
new_model.predict(test_input)
# Out:
# 1/1 [==============================] - 0s 18ms/step
# array([[1.]], dtype=float32)

# %% [markdown]
# ##Using Data Augmentation to treat Overfitting

# %%
from keras.preprocessing.image import ImageDataGenerator

# %%
import os
import shutil

# Define paths
test_dir = "/content/test"

# Create directories for test and validation
test_dest = "/content/test_data"
valid_dest = "/content/valid_data"
os.makedirs(test_dest, exist_ok=True)
os.makedirs(valid_dest, exist_ok=True)

# Define the ratio of test data to validation data (e.g., 80% test, 20% validation)
split_ratio = 0.8

# Iterate over each class directory in the test directory
for class_name in os.listdir(test_dir):
    class_dir = os.path.join(test_dir, class_name)
    if os.path.isdir(class_dir):
        class_images = os.listdir(class_dir)
        num_class_images = len(class_images)
        num_test_class_images = int(num_class_images * split_ratio)

        # Create subdirectories for test and validation data
        test_class_dest = os.path.join(test_dest, class_name)
        valid_class_dest = os.path.join(valid_dest, class_name)
        os.makedirs(test_class_dest, exist_ok=True)
        os.makedirs(valid_class_dest, exist_ok=True)

        # Copy test images to test_data directory
        for img_name in class_images[:num_test_class_images]:
            img_path = os.path.join(class_dir, img_name)
            shutil.copy(img_path, test_class_dest)

        # Copy remaining images to valid_data directory
        for img_name in class_images[num_test_class_images:]:
            img_path = os.path.join(class_dir, img_name)
            shutil.copy(img_path, valid_class_dest)

print("Test data:")
for class_name in os.listdir(test_dest):
    class_dir = os.path.join(test_dest, class_name)
    if os.path.isdir(class_dir):
        print(class_name, len(os.listdir(class_dir)))

print("Validation data:")
for class_name in os.listdir(valid_dest):
    class_dir = os.path.join(valid_dest, class_name)
    if os.path.isdir(class_dir):
        print(class_name, len(os.listdir(class_dir)))
# Out:
# Test data:
# cats 2000
# dogs 2000
# Validation data:
# cats 500
# dogs 500

# %%
batch_size = 16

train_datagen = ImageDataGenerator(
    rescale = 1./255,
    shear_range = 0.2,
    zoom_range = 0.2,
    horizontal_flip = True
)

test_datagen = ImageDataGenerator(rescale = 1./255) #only rescaling

train_generator = train_datagen.flow_from_directory(
    '/content/train',
    target_size=(150,150),
    batch_size=batch_size,
    class_mode='binary'
)

validation_generator = test_datagen.flow_from_directory(
    '/content/valid_data',
    target_size=(150,150),
    batch_size=batch_size,
    class_mode='binary'
)
# Out:
# Found 20000 images belonging to 2 classes.
# Found 1000 images belonging to 2 classes.

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D
from keras.layers import Activation, Dropout, Flatten, Dense


model = Sequential()
model.add(Conv2D(32, (3, 3), input_shape=(150, 150, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(32, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(64, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

# %%
model.add(Flatten())  # this converts our 3D feature maps to 1D feature vectors
model.add(Dense(64))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(1))
model.add(Activation('sigmoid'))

model.compile(loss='binary_crossentropy',
              optimizer='rmsprop',
              metrics=['accuracy'])

# %%
aug_history = model.fit_generator(
        train_generator,
        steps_per_epoch=2000 // batch_size,
        epochs=50,
        validation_data=validation_generator,
        validation_steps=800 // batch_size)
# Out:
# Epoch 1/50
# <ipython-input-139-604528d35d77>:1: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   aug_history = model.fit_generator(
# 125/125 [==============================] - 17s 118ms/step - loss: 0.7001 - accuracy: 0.5100 - val_loss: 0.6969 - val_accuracy: 0.5113
# Epoch 2/50
# 125/125 [==============================] - 15s 118ms/step - loss: 0.6926 - accuracy: 0.5230 - val_loss: 0.6893 - val_accuracy: 0.5663
# Epoch 3/50
# 125/125 [==============================] - 15s 123ms/step - loss: 0.6856 - accuracy: 0.5655 - val_loss: 0.6635 - val_accuracy: 0.6100
# Epoch 4/50
# 125/125 [==============================] - 16s 127ms/step - loss: 0.6702 - accuracy: 0.6105 - val_loss: 0.6525 - val_accuracy: 0.6338
# Epoch 5/50
# 125/125 [==============================] - 16s 124ms/step - loss: 0.6550 - accuracy: 0.6295 - val_loss: 0.6364 - val_accuracy: 0.6300
# Epoch 6/50
# 125/125 [==============================] - 15s 121ms/step - loss: 0.6525 - accuracy: 0.6300 - val_loss: 0.6255 - val_accuracy: 0.6388
# Epoch 7/50
# 125/125 [==============================] - 19s 152ms/step - loss: 0.6496 - accuracy: 0.6375 - val_loss: 0.6226 - val_accuracy: 0.6400
# Epoch 8/50
# 125/125 [==============================] - 14s 113ms/step - loss: 0.6249 - accuracy: 0.6665 - val_loss: 0.6187 - val_accuracy: 0.6425
# Epoch 9/50
# 125/125 [==============================] - 14s 115ms/step - loss: 0.6310 - accuracy: 0.6575 - val_loss: 0.5606 - val_accuracy: 0.7300
# Epoch 10/50
# 125/125 [==============================] - 15s 121ms/step - loss: 0.6069 - accuracy: 0.6780 - val_loss: 0.5570 - val_accuracy: 0.7300
# Epoch 11/50
# 125/125 [==============================] - 14s 114ms/step - loss: 0.5927 - accuracy: 0.6840 - val_loss: 0.5636 - val_accuracy: 0.7425
# Epoch 12/50
# 125/125 [==============================] - 17s 140ms/step - loss: 0.6037 - accuracy: 0.6930 - val_loss: 0.5401 - val_accuracy: 0.7437
# Epoch 13/50
# 125/125 [==============================] - 15s 122ms/step - loss: 0.5960 - accuracy: 0.6825 - val_loss: 0.6420 - val_accuracy: 0.6212
# Epoch 14/50
# 125/125 [==============================] - 14s 113ms/step - loss: 0.5894 - accuracy: 0.6895 - val_loss: 0.6200 - val_accuracy: 0.6675
# Epoch 15/50
# 125/125 [==============================] - 14s 115ms/step - loss: 0.5556 - accuracy: 0.7325 - val_loss: 0.5502 - val_accuracy: 0.7312
# Epoch 16/50
# 125/125 [==============================] - 14s 113ms/step - loss: 0.5781 - accuracy: 0.7060 - val_loss: 0.5162 - val_accuracy: 0.7538
# Epoch 17/50
# 125/125 [==============================] - 15s 117ms/step - loss: 0.5520 - accuracy: 0.7290 - val_loss: 0.4906 - val_accuracy: 0.7738
# Epoch 18/50
# 125/125 [==============================] - 16s 124ms/step - loss: 0.5592 - accuracy: 0.7050 - val_loss: 0.5230 - val_accuracy: 0.7563
# Epoch 19/50
# 125/125 [==============================] - 15s 118ms/step - loss: 0.5606 - accuracy: 0.7195 - val_loss: 0.5359 - val_accuracy: 0.7475
# Epoch 20/50
# 125/125 [==============================] - 16s 125ms/step - loss: 0.5511 - accuracy: 0.7375 - val_loss: 0.5036 - val_accuracy: 0.7412
# Epoch 21/50
# 125/125 [==============================] - 16s 125ms/step - loss: 0.5421 - accuracy: 0.7230 - val_loss: 0.5353 - val_accuracy: 0.7237
# Epoch 22/50
# 125/125 [==============================] - 14s 114ms/step - loss: 0.5451 - accuracy: 0.7285 - val_loss: 0.5043 - val_accuracy: 0.7300
# Epoch 23/50
# 125/125 [==============================] - 14s 116ms/step - loss: 0.5295 - accuracy: 0.7635 - val_loss: 0.5853 - val_accuracy: 0.7100
# Epoch 24/50
# 125/125 [==============================] - 14s 113ms/step - loss: 0.5048 - accuracy: 0.7615 - val_loss: 0.5359 - val_accuracy: 0.7550
# Epoch 25/50
# 125/125 [==============================] - 16s 125ms/step - loss: 0.5350 - accuracy: 0.7385 - val_loss: 0.4632 - val_accuracy: 0.7750
# Epoch 26/50
# 125/125 [==============================] - 15s 117ms/step - loss: 0.4865 - accuracy: 0.7640 - val_loss: 0.7259 - val_accuracy: 0.7100
# Epoch 27/50
# 125/125 [==============================] - 16s 125ms/step - loss: 0.5347 - accuracy: 0.7375 - val_loss: 0.4464 - val_accuracy: 0.7825
# Epoch 28/50
# 125/125 [==============================] - 14s 115ms/step - loss: 0.4999 - accuracy: 0.7685 - val_loss: 0.4418 - val_accuracy: 0.7975
# Epoch 29/50
# 125/125 [==============================] - 14s 115ms/step - loss: 0.5000 - accuracy: 0.7610 - val_loss: 0.4446 - val_accuracy: 0.7962
# Epoch 30/50
# 125/125 [==============================] - 14s 114ms/step - loss: 0.5136 - accuracy: 0.7630 - val_loss: 0.4719 - val_accuracy: 0.7825
# Epoch 31/50
# 125/125 [==============================] - 14s 116ms/step - loss: 0.4843 - accuracy: 0.7770 - val_loss: 0.4855 - val_accuracy: 0.7675
# Epoch 32/50
# 125/125 [==============================] - 14s 115ms/step - loss: 0.5121 - accuracy: 0.7585 - val_loss: 0.4354 - val_accuracy: 0.7962
# Epoch 33/50
# 125/125 [==============================] - 15s 120ms/step - loss: 0.4965 - accuracy: 0.7615 - val_loss: 0.4754 - val_accuracy: 0.7825
# Epoch 34/50
# 125/125 [==============================] - 16s 128ms/step - loss: 0.5054 - accuracy: 0.7540 - val_loss: 0.4512 - val_accuracy: 0.7950
# Epoch 35/50
# 125/125 [==============================] - 14s 114ms/step - loss: 0.4823 - accuracy: 0.7840 - val_loss: 0.4543 - val_accuracy: 0.7763
# Epoch 36/50
# 125/125 [==============================] - 14s 114ms/step - loss: 0.4928 - accuracy: 0.7750 - val_loss: 0.4656 - val_accuracy: 0.7862
# Epoch 37/50
# 125/125 [==============================] - 14s 114ms/step - loss: 0.5021 - accuracy: 0.7730 - val_loss: 0.4380 - val_accuracy: 0.7900
# Epoch 38/50
# 125/125 [==============================] - 14s 113ms/step - loss: 0.4828 - accuracy: 0.7695 - val_loss: 0.4830 - val_accuracy: 0.7763
# Epoch 39/50
# 125/125 [==============================] - 16s 125ms/step - loss: 0.4670 - accuracy: 0.7885 - val_loss: 0.4250 - val_accuracy: 0.8213
# Epoch 40/50
# 125/125 [==============================] - 15s 116ms/step - loss: 0.4724 - accuracy: 0.7785 - val_loss: 0.4517 - val_accuracy: 0.7862
# Epoch 41/50
# 125/125 [==============================] - 14s 115ms/step - loss: 0.4667 - accuracy: 0.7965 - val_loss: 0.4135 - val_accuracy: 0.8062
# Epoch 42/50
# 125/125 [==============================] - 14s 114ms/step - loss: 0.4711 - accuracy: 0.7830 - val_loss: 0.4196 - val_accuracy: 0.8100
# Epoch 43/50
# 125/125 [==============================] - 14s 115ms/step - loss: 0.4845 - accuracy: 0.7740 - val_loss: 0.4201 - val_accuracy: 0.7975
# Epoch 44/50
# 125/125 [==============================] - 14s 116ms/step - loss: 0.4634 - accuracy: 0.7885 - val_loss: 0.4116 - val_accuracy: 0.8037
# Epoch 45/50
# 125/125 [==============================] - 14s 114ms/step - loss: 0.4319 - accuracy: 0.7990 - val_loss: 0.4621 - val_accuracy: 0.7825
# Epoch 46/50
# 125/125 [==============================] - 15s 123ms/step - loss: 0.4536 - accuracy: 0.8120 - val_loss: 0.5523 - val_accuracy: 0.7688
# Epoch 47/50
# 125/125 [==============================] - 15s 117ms/step - loss: 0.4843 - accuracy: 0.7775 - val_loss: 0.4465 - val_accuracy: 0.7875
# Epoch 48/50
# 125/125 [==============================] - 14s 116ms/step - loss: 0.4620 - accuracy: 0.7845 - val_loss: 0.4305 - val_accuracy: 0.7987
# Epoch 49/50
# 125/125 [==============================] - 16s 125ms/step - loss: 0.4321 - accuracy: 0.8085 - val_loss: 0.4174 - val_accuracy: 0.8225
# Epoch 50/50
# 125/125 [==============================] - 14s 114ms/step - loss: 0.4562 - accuracy: 0.7875 - val_loss: 0.3895 - val_accuracy: 0.8138

# %%
import matplotlib.pyplot as plt

plt.plot(aug_history.history['accuracy'],color='red',label='train')
plt.plot(aug_history.history['val_accuracy'],color='blue',label='validation')
plt.legend()
plt.show()

# %%
plt.plot(aug_history.history['loss'],color='red',label='train')
plt.plot(aug_history.history['val_loss'],color='blue',label='validation')
plt.legend()
plt.show()

# %% [markdown]
# Training and Validation loss follows each other

# %% [markdown]
# TEST

# %%
model.predict(test_inputpet) #/content/myhousecat.jpg?raw=true
# Out:
# 1/1 [==============================] - 1s 547ms/step
# array([[0.]], dtype=float32)

# %%
model.predict(test_input) #/content/dog.jpg?raw=true
# Out:
# 1/1 [==============================] - 0s 18ms/step
# array([[1.]], dtype=float32)
